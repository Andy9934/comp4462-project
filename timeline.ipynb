# %%
import plotly.graph_objects as go
import pandas as pd

# %%
import os 
os.chdir('drive/MyDrive/comp4462/MC3')
os.getcwd()
# Out:
# '/content/drive/MyDrive/comp4462/MC3'

# %%
df = pd.read_csv('df_final.csv')
df
# Out:
#        Unnamed: 0  ...                 hashtag
# 0               0  ...                      []
# 1               1  ...     ['MakesItyoureCan']
# 2               2  ...                      []
# 3               3  ...                      []
# 4               4  ...  ['rumble', 'toWonder']
# ...           ...  ...                     ...
# 41936       41936  ...                      []
# 41937       41937  ...                      []
# 41938       41938  ...                      []
# 41939       41939  ...                      []
# 41940       41940  ...                      []
#
# [41941 rows x 7 columns]

# %%
by_hour = pd.to_datetime(df['time']).dt.to_period("H").value_counts().sort_index()
by_hour.index = pd.PeriodIndex(by_hour.index)

df_hour = by_hour.rename_axis('hour').reset_index(name='counts')
df_hour
# Out:
#                  hour  counts
# 0    2020-04-06 00:00      24
# 1    2020-04-06 01:00      18
# 2    2020-04-06 02:00      22
# 3    2020-04-06 03:00      34
# 4    2020-04-06 04:00      76
# ..                ...     ...
# 103  2020-04-10 07:00     766
# 104  2020-04-10 08:00     312
# 105  2020-04-10 09:00     617
# 106  2020-04-10 10:00     357
# 107  2020-04-10 11:00     536
#
# [108 rows x 2 columns]

# %%
#overall tweets count over hour
fig = go.Figure(go.Scatter(
    x=df_hour['hour'].astype(dtype=str), 
    y=df_hour['counts'], 
    marker_color='blue',
    text="counts"))

fig.update_xaxes(
    rangeslider_visible=True,
    # tickformatstops = [
    #     dict(dtickrange=[None, 1000], value="%H:%M:%S.%L ms"),
    #     dict(dtickrange=[1000, 60000], value="%H:%M:%S s"),
    #     dict(dtickrange=[60000, 3600000], value="%H:%M m"),
    #     dict(dtickrange=[3600000, 86400000], value="%H:%M h"),
    #     dict(dtickrange=[86400000, 604800000], value="%e. %b d"),
    #     dict(dtickrange=[604800000, "M1"], value="%e. %b w"),
    #     dict(dtickrange=["M1", "M12"], value="%b '%y M"),
    #     dict(dtickrange=["M12", None], value="%Y Y")
    # ]
)

fig.update_layout({
    "title": 'Tweets count from 2020-04-06 to 2020-04-10 hour by hour',
    "xaxis": {"title":"Time"},
    "yaxis": {"title":"Total tweets count"},
    "showlegend": False
})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="34675246-5fae-4cb4-891a-c1e0fe17f88b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34675246-5fae-4cb4-891a-c1e0fe17f88b")) {
#                     Plotly.newPlot(
#                         '34675246-5fae-4cb4-891a-c1e0fe17f88b',
#                         [{"marker": {"color": "blue"}, "text": "counts", "type": "scatter", "x": ["2020-04-06 00:00", "2020-04-06 01:00", "2020-04-06 02:00", "2020-04-06 03:00", "2020-04-06 04:00", "2020-04-06 05:00", "2020-04-06 06:00", "2020-04-06 07:00", "2020-04-06 08:00", "2020-04-06 09:00", "2020-04-06 10:00", "2020-04-06 11:00", "2020-04-06 12:00", "2020-04-06 13:00", "2020-04-06 14:00", "2020-04-06 15:00", "2020-04-06 16:00", "2020-04-06 17:00", "2020-04-06 18:00", "2020-04-06 19:00", "2020-04-06 20:00", "2020-04-06 21:00", "2020-04-06 22:00", "2020-04-06 23:00", "2020-04-07 00:00", "2
# 0        2020-04-06 00:00:00
# 20       2020-04-06 00:50:00
# 26       2020-04-06 01:08:00
# 39       2020-04-06 01:40:00
# 40       2020-04-06 01:48:00
#                 ...
# 41898    2020-04-10 11:54:00
# 41908    2020-04-10 11:55:00
# 41921    2020-04-10 11:57:00
# 41922    2020-04-10 11:57:00
# 41939    2020-04-10 11:59:00
# Name: time, Length: 4641, dtype: object

# %%
df_region = []
for region in list_region:
  by_hour = pd.to_datetime(df['time'].loc[df['location']==region]).dt.to_period("H").value_counts().sort_index()
  by_hour.index = pd.PeriodIndex(by_hour.index)

  df_hour = by_hour.rename_axis('hour').reset_index(name='counts')
  df_region.append(df_hour)

# %%
trace1 = {
    'x': df[x],
    'y': df[y1],
    'type': 'scatter',
    'mode': 'lines',
    'name':'col 1',
    'marker': {'color': 'blue'}
}

trace2={
    'x': df[x],
    'y': df[y2],
    'type': 'scatter',
    'mode': 'lines',
    'name':'col 2',
    'marker': {'color': 'yellow'}
}

data = [trace1, trace2]

# Create layout for the plot
layout=dict(
    title='my plot',
    xaxis=dict(
        title='Date', 
        type='date', 
        tickformat='%Y-%m-%d', 
        ticklen=5, 
        titlefont=dict(
            family='Old Standard TT, serif',
            size=20,
            color='black'
        )
    ),
    yaxis=dict(
        title='values', 
        ticklen=5,
        titlefont=dict(
            family='Old Standard TT, serif',
            size=20,
            color='black'
            )
        )

    )

# Here's the new part

fig = go.FigureWidget(data=data, layout=layout)

def update_fig(change):
    aux_df = df[df.category.isin(change['new'])]
    with fig.batch_update():
        for trace, column in zip(fig.data, [y1, y2]):
            trace.x = aux_df[x]
            trace.y = aux_df[column]

drop = w.Dropdown(options=[
    ('All', ['G1', 'G2']),
    ('G1', ['G1']),
    ('G2', ['G2']),
])
drop.observe(update_fig, names='value')

display(w.VBox([drop, fig]))

# %%
fig.add_trace(
    go.Scatter(x=list(df.index),
               y=list(df.High),
               name="High",
               line=dict(color="#33CFA5")))

fig.add_trace(
    go.Scatter(x=list(df.index),
               y=[df.High.mean()] * len(df.index),
               name="High Average",
               visible=False,
               line=dict(color="#33CFA5", dash="dash")))

fig.add_trace(
    go.Scatter(x=list(df.index),
               y=list(df.Low),
               name="Low",
               line=dict(color="#F06A6A")))

fig.add_trace(
    go.Scatter(x=list(df.index),
               y=[df.Low.mean()] * len(df.index),
               name="Low Average",
               visible=False,
               line=dict(color="#F06A6A", dash="dash")))

fig.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=list([
                dict(label="None",
                     method="update",
                     args=[{"visible": [True, False, True, False]},
                           {"title": "Yahoo",
                            "annotations": []}]),
                dict(label="High",
                     method="update",
                     args=[{"visible": [True, True, False, False]},
                           {"title": "Yahoo High",
                            "annotations": high_annotations}]),
                dict(label="Low",
                     method="update",
                     args=[{"visible": [False, False, True, True]},
                           {"title": "Yahoo Low",
                            "annotations": low_annotations}]),
                dict(label="Both",
                     method="update",
                     args=[{"visible": [True, True, True, True]},
                           {"title": "Yahoo",
                            "annotations": high_annotations + low_annotations}]),
            ]),
        )
    ])

# %%
#dropdown timeline count for different region
fig = go.Figure()
#color list for different region
color_list = ["#4E79A7","#A0CBE8", "#F28E2B","#FFBE7D","#59A14F","#8CD17D","#B6992D","#F1CE63","#499894","#86BCB6","#E15759","#FF9D9A","#79706E","#BAB0AC","#D37295","#FABFD2","#B07AA1","#D4A6C8","#9D7660","#D7B5A6", "#000000"]
for idx, region in enumerate(list_region):
  fig.add_trace(
      go.Scatter(x=df_region[idx]['hour'].astype(dtype=str),
                y=df_region[idx]['counts'],
                name=region,
                text="counts",
                line=dict(color=color_list[idx])))
  
fig.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=list([
                dict(label=list_region[0],
                     method="update",
                     args=[{"visible": [True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[1],
                     method="update",
                     args=[{"visible": [False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[2],
                    method="update",
                    args=[{"visible": [False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                          {"title": "Tweets Count"}]),                     
                dict(label=list_region[3],
                     method="update",
                     args=[{"visible": [False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[4],
                     method="update",
                     args=[{"visible": [False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[5],
                    method="update",
                    args=[{"visible": [False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                          {"title": "Tweets Count"}]),
                dict(label=list_region[6],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[7],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[8],
                    method="update",
                    args=[{"visible": [False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False]},
                          {"title": "Tweets Count"}]),
                dict(label=list_region[9],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[10],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[11],
                    method="update",
                    args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False]},
                          {"title": "Tweets Count"}]),
                dict(label=list_region[12],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[13],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[14],
                    method="update",
                    args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False]},
                          {"title": "Tweets Count"}]),
                dict(label=list_region[15],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[16],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[17],
                    method="update",
                    args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False]},
                          {"title": "Tweets Count"}]),
                 dict(label=list_region[18],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[19],
                     method="update",
                     args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False]},
                           {"title": "Tweets Count"}]),
                dict(label=list_region[20],
                    method="update",
                    args=[{"visible": [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True]},
                          {"title": "Tweets Count"}]),                                                                                                                            
            ]),
        )
    ])

fig.update_xaxes(
    rangeslider_visible=True,
)

fig.update_layout({
    "title": 'Tweets count from 2020-04-06 to 2020-04-10 hour by hour',
    "xaxis": {"title":"Time"},
    "yaxis": {"title":"Total tweets count"},
    "showlegend": False
})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e5e2ebf-57e9-49cf-8757-34a4bf6066a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e5e2ebf-57e9-49cf-8757-34a4bf6066a8")) {
#                     Plotly.newPlot(
#                         '7e5e2ebf-57e9-49cf-8757-34a4bf6066a8',
#                         [{"line": {"color": "#4E79A7"}, "name": "Weston", "text": "counts", "type": "scatter", "x": ["2020-04-06 00:00", "2020-04-06 01:00", "2020-04-06 02:00", "2020-04-06 03:00", "2020-04-06 04:00", "2020-04-06 05:00", "2020-04-06 06:00", "2020-04-06 07:00", "2020-04-06 08:00", "2020-04-06 09:00", "2020-04-06 10:00", "2020-04-06 11:00", "2020-04-06 12:00", "2020-04-06 13:00", "2020-04-06 14:00", "2020-04-06 15:00", "2020-04-06 16:00", "2020-04-06 17:00", "2020-04-06 18:00", "2020-04-06 19:00", "2020-04-06 20:00", "2020-04-06 21:00", "2020-04-06 22:00", "2020-04-06 23:00", "2020-04-07 00:00", "2020-04-07 01:00", "2020-04-07 02:00", "2020-04-07 03:00", "2020-04-07 04:00", "2020-04-07 05:00", "2020-04-07 06:00", "2020-04-07 07:00", "2020-04-07 08:00", "2020-04-07 09:00", "2020-04-07 10:00", "2020-04-07 11:00", "2020-04-07 12:00", "2020-04-07 13:00", "2020-04-07 14:00", "2020-04-07 15:00", "2020-04-07 16:00", "2020-04-07 17:00", "2020-04-07 18:00", "2020-04-07 19:00", "2020-04-07 20:00", "2